# %%
pip install xlsxwriter
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
from IPython.display import FileLink
#data frame form Yahoo Finance 
import yfinance as yf
from requests.exceptions import HTTPError
import pandas as pd

# %% [markdown]
# #  Data

# %% [markdown]
# ## Companies 1-100

# %%
# URL of the web page
url = 'https://companiesmarketcap.com/india/largest-companies-in-india-by-market-cap/?page=1' 

#url= "https://www1.nseindia.com/products/content/equities/equities/eq_security.htm"

# Send a GET request to the website
response = requests.get(url)

# Parse the HTML content of the page with BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Find the HTML element(s) that contain the company names and symbols
company_elements = soup.find_all('div', class_='name-div')

# Extract and print the company names and symbols
for element in company_elements:
    company_name = element.find('div', class_='company-name').text.strip()
    company_symbol = element.find('div', class_='company-code').text.strip()
    print(f"{company_name} {company_symbol}")
# Out:
# Reliance Industries RELIANCE.NS
# Tata Consultancy Services TCS.NS
# HDFC Bank HDB
# ICICI Bank IBN
# Infosys INFY
# State Bank of India SBIN.NS
# Life Insurance Corporation of India (LIC) LICI.NS
# Bharti Airtel BHARTIARTL.NS
# Hindustan Unilever HINDUNILVR.NS
# ITC ITC.NS
# Larsen & Toubro LT.NS
# HCL Technologies HCLTECH.NS
# Bajaj Finance BAJFINANCE.NS
# Sun Pharmaceutical SUNPHARMA.NS
# Adani Enterprises ADANIENT.NS
# Maruti Suzuki India MARUTI.NS
# Tata Motors TATAMOTORS.NS
# Kotak Mahindra Bank KOTAKBANK.NS
# Oil & Natural Gas ONGC.NS
# Axis Bank AXISBANK.BO
# Titan Company TITAN.NS
# NTPC Limited NTPC.NS
# Adani Green Energy ADANIGREEN.NS
# UltraTech Cement ULTRACEMCO.NS
# Asian Paints ASIANPAINT.NS
# Adani Ports & SEZ ADANIPORTS.NS
# Wipro WIT
# Coal India COALINDIA.NS
# Powergrid Corporation of India POWERGRID.NS
# Bajaj Finserv BAJAJFINSV.NS
# DMart DMART.NS
# Nestlé India NESTLEIND.NS
# Indian Oil IOC.NS
# Mahindra & Mahindra M&M.NS
# Bajaj Auto BAJAJ-AUTO.NS
# ...

# %% [markdown]
# ## COMPANIES 101 - 200

# %%
# URL of the web page
url = 'https://companiesmarketcap.com/india/largest-companies-in-india-by-market-cap/?page=2' 

# Send a GET request to the website
response = requests.get(url)

# Parse the HTML content of the page with BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Find the HTML element(s) that contain the company names and symbols
company_elements = soup.find_all('div', class_='name-div')

# Extract and print the company names and symbols
for element in company_elements:
    company_name = element.find('div', class_='company-name').text.strip()
    company_symbol = element.find('div', class_='company-code').text.strip()
    print(f"{company_name} {company_symbol}")
# Out:
# Vodafone Idea IDEA.NS
# Yes Bank YESBANK.NS
# Samvardhana Motherson MOTHERSON.NS
# Cummins India CUMMINSIND.NS
# Hindustan Petroleum HINDPETRO.NS
# General Insurance Corporation of India GICRE.NS
# Indian Railway Catering & Tourism IRCTC.NS
# ICICI Prulife ICICIPRULI.NS
# Lupin Limited LUPIN.NS
# SRF Limited SRF.NS
# Tube Investments of India TIINDIA.NS
# Indian Bank INDIANB.NS
# Polycab India POLYCAB.NS
# SBI Card SBICARD.NS
# National Mineral Development Corporation NMDC.NS
# Marico MARICO.NS
# Colgate-Palmolive India COLPAL.NS
# Info Edge NAUKRI.NS
# Berger Paints BERGEPAINT.NS
# Godrej Properties GODREJPROP.NS
# Persistent Systems PERSISTENT.NS
# Oil India OIL.NS
# CG Power and Industrial Solutions CGPOWER.NS
# Alkem Laboratories ALKEM.NS
# Madras Rubber Factory MRF.NS
# Bank of India BANKINDIA.NS
# Container Corporation of India CONCOR.NS
# Solar Industries India SOLARINDS.NS
# Aurobindo Pharma AUROPHARMA.NS
# Abbott India ABBOTINDIA.NS
# Suzlon SUZLON.NS
# ...

# %% [markdown]
# ## Companies 201-300

# %%
# URL of the web page
url = 'https://companiesmarketcap.com/india/largest-companies-in-india-by-market-cap/?page=3' 

# Send a GET request to the website
response = requests.get(url)

# Parse the HTML content of the page with BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Find the HTML element(s) that contain the company names and symbols
company_elements = soup.find_all('div', class_='name-div')

# Extract and print the company names and symbols
for element in company_elements:
    company_name = element.find('div', class_='company-name').text.strip()
    company_symbol = element.find('div', class_='company-code').text.strip()
    print(f"{company_name} {company_symbol}")
# Out:
# Escorts Limited ESCORTS.NS
# Gland Pharma GLAND.NS
# Ipca Laboratories IPCALAB.NS
# Indraprastha Gas IGL.NS
# KIOCL KIOCL.NS
# Indian Telephone Industries ITI.NS
# Syngene International SYNGENE.NS
# BSE BSE.NS
# National Aluminum & Alloy NATIONALUM.NS
# Exide Industries EXIDEIND.NS
# Bayer Crop Science BAYERCROP.NS
# ZF Commercial Vehicle Control Systems India ZFCVINDIA.NS
# JBM Auto JBMA.NS
# NBCC India NBCC.NS
# Blue Star BLUESTARCO.NS
# Glenmark Pharmaceuticals GLENMARK.NS
# Endurance Technologies ENDURANCE.NS
# Apar Industries APARINDS.NS
# Hindustan Copper HINDCOPPER.NS
# Tata Chemicals TATACHEM.NS
# Nerolac Paints KANSAINER.NS
# EIH Limited EIHOTEL.NS
# Aarti Industries AARTIIND.NS
# Paytm PAYTM.NS
# Sun TV Network SUNTV.NS
# Hatsun Agro Products HATSUN.NS
# Vedant Fashions MANYAVAR.NS
# Grindwell Norton GRINDWELL.NS
# WNS WNS
# IIFL Finance IIFL.NS
# Cyient CYIENT.NS
# SKF India SKFINDIA.NS
# Trident TRIDENT.NS
# Radico Khaitan RADICO.NS
# ...

# %% [markdown]
# ## Companies 301-400

# %%
# URL of the web page
url = 'https://companiesmarketcap.com/india/largest-companies-in-india-by-market-cap/?page=4' 

# Send a GET request to the website
response = requests.get(url)

# Parse the HTML content of the page with BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Find the HTML element(s) that contain the company names and symbols
company_elements = soup.find_all('div', class_='name-div')

# Extract and print the company names and symbols
for element in company_elements:
    company_name = element.find('div', class_='company-name').text.strip()
    company_symbol = element.find('div', class_='company-code').text.strip()
    print(f"{company_name} {company_symbol}")
# Out:
# BEML BEML.NS
# MMTC MMTC.NS
# Raymond RAYMOND.NS
# Engineers India ENGINERSIN.NS
# Happiest Minds Technologies HAPPSTMNDS.NS
# Network18 NETWORK18.NS
# Zensar ZENSARTECH.NS
# eClerx Services ECLERX.NS
# Bombay Burmah BBTC.NS
# Graphite India GRAPHITE.NS
# CEAT CEATLTD.NS
# Bajaj Electricals BAJAJELEC.NS
# Sheela Foam SFL.NS
# Anant Raj ANANTRAJ.NS
# Aavas Financiers AAVAS.NS
# PCBL Limited PCBL.NS
# Aether Industries AETHER.NS
# SPARC SPARC.NS
# KFin Technologies KFINTECH.NS
# East India Distilleries Parry EIDPARRY.NS
# Granules India GRANULES.NS
# Electrosteel Castings ELECTCAST.NS
# Ingersoll Rand India INGERRAND.NS
# Indiabulls Housing Finance IBULHSGFIN.NS
# Amara Raja Batteries AMARAJABAT.NS
# Godawari Power & Ispat GPIL.NS
# Zydus Wellness ZYDUSWELL.NS
# City Union Bank CUB.NS
# Rajesh Exports RAJESHEXPO.NS
# Reliance Power RPOWER.NS
# Infibeam Avenues INFIBEAM.NS
# MapmyIndia MAPMYINDIA.NS
# Cera Sanitaryware CERA.NS
# Safari Industries India SAFARI.NS
# ...

# %% [markdown]
# ## Companis 401-500

# %%
# URL of the web page
url = 'https://companiesmarketcap.com/india/largest-companies-in-india-by-market-cap/?page=5' 

# Send a GET request to the website
response = requests.get(url)

# Parse the HTML content of the page with BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Find the HTML element(s) that contain the company names and symbols
company_elements = soup.find_all('div', class_='name-div')

# Extract and print the company names and symbols
for element in company_elements:
    company_name = element.find('div', class_='company-name').text.strip()
    company_symbol = element.find('div', class_='company-code').text.strip()
    print(f"{company_name} {company_symbol}")
# Out:
# RattanIndia Power RTNPOWER.NS
# Suprajit Engineering SUPRAJIT.NS
# Wonderla Holidays WONDERLA.NS
# Gateway Distriparks GATEWAY.NS
# Orient Cement ORIENTCEM.NS
# Gabriel India GABRIEL.NS
# VRL Logistics VRLLOG.NS
# National Fertilizers NFL.NS
# Ashoka Buildcon ASHOKA.NS
# Time Technoplast TIMETECHNO.NS
# Aarti Drugs AARTIDRUGS.NS
# Sundaram Finance SUNDARMHLD.NS
# Gulf Oil Lubricants GULFOILLUB.NS
# Heidelbergcement India HEIDELBERG.NS
# eMudhra EMUDHRA.NS
# Kewal Kiran Clothing KKCL.NS
# VA Tech Wabag WABAG.NS
# Black Box BBOX.NS
# The Tinplate Company Of India TINPLATE.NS
# Greenpanel Industries GREENPANEL.NS
# Orient Electric ORIENTELEC.NS
# Dish TV DISHTV.NS
# West Coast Paper Mills WSTCSTPAPR.NS
# Hathway HATHWAY.NS
# Hinduja Global Solutions HGS.NS
# Sudarshan Chemical SUDARSCHEM.NS
# SpiceJet SPICEJET.BO
# Imagicaaworld Entertainment IMAGICAA.NS
# Unitech Group UNITECH.NS
# Subros SUBROS.NS
# Jain Irrigation Systems JISLDVREQS.NS
# Kaveri Seed KSCL.NS
# Delta Corp DELTACORP.NS
# ...

# %% [markdown]
# ## Companies 501-568

# %%
# URL of the web page
url = 'https://companiesmarketcap.com/india/largest-companies-in-india-by-market-cap/?page=6' 

# Send a GET request to the website
response = requests.get(url)

# Parse the HTML content of the page with BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Find the HTML element(s) that contain the company names and symbols
company_elements = soup.find_all('div', class_='name-div')

# Extract and print the company names and symbols
for element in company_elements:
    company_name = element.find('div', class_='company-name').text.strip()
    company_symbol = element.find('div', class_='company-code').text.strip()
    print(f"{company_name} {company_symbol}")
# Out:
# Omaxe OMAXE.NS
# Federal-Mogul Goetze FMGOETZE.NS
# Hindustan Sanitaryware & Industries HSIL.NS
# GE Power India GEPIL.NS
# Southern Petrochemical Industries Corp SPIC.NS
# Mangalam Cement MANGLMCEM.NS
# Sify SIFY
# Geojit Financial Services GEOJITFSL.NS
# Tamil Nadu Newsprint and Papers Limited TNPL.NS
# Shankara Building SHANKARA.NS
# Gallantt Ispat GALLISPAT.NS
# Nelco NELCO.NS
# Astec Lifesciences ASTEC.NS
# Gati GATI.NS
# Kitex Garments KITEX.NS
# India Nippon Electricals INDNIPPON.NS
# Navkar Corp NAVKARCORP.NS
# Dhampur Sugar Mills DHAMPURSUG.NS
# Rane Holdings RANEHOLDIN.NS
# Igarashi Motors India IGARASHI.NS
# Himatsingka Seide HIMATSEIDE.NS
# Wheels India WHEELS.NS
# I.g. Petrochemicals IGPL.NS
# INEOS Styrolution INEOSSTYRO.NS
# NACL Industries NACLIND.NS
# Mangalore Chemicals and Fertilizers MANGCHEFER.NS
# Kuantum Papers KUANTUM.NS
# Cosmo First COSMOFIRST.NS
# Balaji Telefilms BALAJITELE.NS
# Jay Bharat Maruti JAYBARMARU.NS
# Monte Carlo Fashions MONTECARLO.NS
# ...

# %% [markdown]
# ## Data Frame of all the companies' data

# %%
import yfinance as yf
from requests.exceptions import HTTPError
import pandas as pd

# List of ticker symbols
ticker_symbols = [
    "RELIANCE.NS",
    "TCS.NS",
    "HDB",
    "IBN",
    "INFY",
    "SBIN.NS",
    "LICI.NS",
    "BHARTIARTL.NS",
    "HINDUNILVR.NS",
    "ITC.NS",
    "LT.NS",
    "HCLTECH.NS",
    "BAJFINANCE.NS",
    "SUNPHARMA.NS",
    "ADANIENT.NS",
    "MARUTI.NS",
    "TATAMOTORS.NS",
    "KOTAKBANK.NS",
    "ONGC.NS",
    "AXISBANK.BO",
    "TITAN.NS",
    "NTPC.NS",
    "ADANIGREEN.NS",
    "ULTRACEMCO.NS",
    "ASIANPAINT.NS",
    "ADANIPORTS.NS",
    "WIT",
    "COALINDIA.NS",
    "POWERGRID.NS",
    "BAJAJFINSV.NS",
    "DMART.NS",
    "NESTLEIND.NS",
    "IOC.NS",
    "M&M.NS",
    "BAJAJ-AUTO.NS",
    "DLF.NS",
    "MANGLMCEM.NS",
    "SIFY",
    "GEOJITFSL.NS",
    "TNPL.NS",
    "SHANKARA.NS",
    "GALLISPAT.NS",
    "NELCO.NS",
    "ASTEC.NS",
    "GATI.NS",
    "KITEX.NS",
    "INDNIPPON.NS",
    "NAVKARCORP.NS",
    "DHAMPURSUG.NS",
    "RANEHOLDIN.NS",
    "IGARASHI.NS",
    "HIMATSEIDE.NS",
    "WHEELS.NS",
    "IGPL.NS",
    "INEOSSTYRO.NS",
    "NACLIND.NS",
    "MANGCHEFER.NS",
    "KUANTUM.NS",
    "COSMOFIRST.NS",
    "BALAJITELE.NS",
    "JAYBARMARU.NS",
    "MONTECARLO.NS",
    "APTECHT.NS",
    "IMPAL.NS",
    "INDORAMA.NS",
    "KOKUYOCMLN.NS",
    "COFFEEDAY.NS",
    "BLISSGVS.NS",
    "STERTOOLS.NS",
    "RICOAUTO.NS",
    "OAL.NS",
    "HESTERBIO.NS",
    "SPENCERS.NS",
    "ORIENTPPR.NS",
    "EXCELINDUS.NS",
    "BODALCHEM.NS",
    "KELLTONTEC.NS",
    "NECLIFE.NS",
    "HMVL.NS",
    "3IINFOLTD.NS",
    "YTRA",
    "ASIANTILES.NS",
    "RADIOCITY.NS",
    "APEX.NS",
    "MIRZAINT.NS",
    "EBIXFOREX.NS",
    "RCOM.NS",
    "RBL.NS",
    "NBIFIN.NS",
    "NXTDIGITAL.NS",
    "ZEELEARN.NS",
    "MEP.NS",
    "MLKFOOD.BO",
    "FRETAIL.NS",
    "SREINFRA.NS",
    "JUMPNET.NS",
    "MODAIRY.BO",
    "FSC.NS"
        
]


# Counters
total_companies = len(ticker_symbols)
discarded_companies = 0
available_companies = 0

# Set start and end dates
start_date = '2014-01-01'
end_date = '2024-1-31'

# Create an empty DataFrame to store data for companies with sector and industry
all_stock_data = pd.DataFrame()

# Loop through each ticker symbol
for ticker_symbol in ticker_symbols:
    try:
        # Create a Ticker object
        ticker = yf.Ticker(ticker_symbol)

        # Get the info dictionary containing various information including sector and industry
        info = ticker.info

        # Get sector and industry information
        sector = info.get('sector')
        industry = info.get('industry')

        # Check if both sector and industry are not None
        if sector is not None and industry is not None:
            # Download historical data for the current ticker symbol
            stock_data = yf.download(ticker_symbol, start=start_date, end=end_date)

            # Add stock information as columns to the DataFrame
            stock_data['Company Name'] = info['longName']
            stock_data['Sector'] = sector
            stock_data['Industry'] = industry

            # Append the stock data to the DataFrame for all stocks
            all_stock_data = pd.concat([all_stock_data, stock_data])

            available_companies += 1
        else:
            discarded_companies += 1
    except HTTPError as e:
        if e.response.status_code == 404:
            print(f"Error 404: Ticker {ticker_symbol} not found. Discarding...")
            discarded_companies += 1

# Reset index to include the 'Date' column in the Excel file
all_stock_data.reset_index(inplace=True)

# Save the data to an Excel file
#all_stock_data.to_excel('stock_data.xlsx', index=False)

# Print summary
print("Summary:")
print("Total companies input:", total_companies)
print("Number of companies discarded:", discarded_companies)
print("Number of companies available with sector and industry:", available_companies)
print("Data saved to stock_data.xlsx")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %%
import yfinance as yf
from requests.exceptions import HTTPError
import pandas as pd



ticker_symbols = [
    "RELIANCE.NS",
    "TCS.NS",
    "HDB",
    "IBN",
    "INFY",
    "SBIN.NS",
    "LICI.NS",
    "BHARTIARTL.NS",
    "HINDUNILVR.NS",
    "ITC.NS",
    "LT.NS",
    "HCLTECH.NS",
    "BAJFINANCE.NS",
    "SUNPHARMA.NS",
    "ADANIENT.NS",
    "MARUTI.NS",
    "TATAMOTORS.NS",
    "KOTAKBANK.NS",
    "ONGC.NS",
    "AXISBANK.BO",
    "TITAN.NS",
    "NTPC.NS",
    "ADANIGREEN.NS",
    "ULTRACEMCO.NS",
    "ASIANPAINT.NS",
    
]

# Counters
total_companies = len(ticker_symbols)
discarded_companies = 0
available_companies = 0

# Set start and end dates
start_date = '2014-01-01'
end_date = '2024-1-31'

# Create an empty DataFrame to store data for companies with sector and industry
all_stock_data = pd.DataFrame()

# Loop through each ticker symbol
for ticker_symbol in ticker_symbols:
    try:
        # Create a Ticker object
        ticker = yf.Ticker(ticker_symbol)

        # Get the info dictionary containing various information including sector and industry
        info = ticker.info

        # Get sector and industry information
        sector = info.get('sector')
        industry = info.get('industry')

        # Check if both sector and industry are not None
        if sector is not None and industry is not None:
            # Download historical data for the current ticker symbol
            stock_data = yf.download(ticker_symbol, start=start_date, end=end_date)

            # Add stock information as columns to the DataFrame
            stock_data['Company Name'] = info['longName']
            stock_data['Sector'] = sector
            stock_data['Industry'] = industry

            # Append the stock data to the DataFrame for all stocks
            all_stock_data = pd.concat([all_stock_data, stock_data])

            available_companies += 1
        else:
            discarded_companies += 1
    except HTTPError as e:
        if e.response.status_code == 404:
            print(f"Error 404: Ticker {ticker_symbol} not found. Discarding...")
            discarded_companies += 1

# Reset index to include the 'Date' column in the Excel file
all_stock_data.reset_index(inplace=True)

# Save the data to an Excel file
all_stock_data.to_excel('stock_data.xlsx', index=False)

# Print summary
print("Summary:")
print("Total companies input:", total_companies)
print("Number of companies discarded:", discarded_companies)
print("Number of companies available with sector and industry:", available_companies)
print("Data saved to stock_data.xlsx")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %%
import yfinance as yf
from requests.exceptions import HTTPError
import pandas as pd

# List of ticker symbols
ticker_symbols = [
    "RELIANCE.NS",
    "TCS.NS",
    "HDB",
    "IBN",
    "INFY",
    "SBIN.NS",
    "LICI.NS",
    "BHARTIARTL.NS",
    "HINDUNILVR.NS",
    "ITC.NS",
    "LT.NS",
    "HCLTECH.NS",
    "BAJFINANCE.NS",
    "SUNPHARMA.NS",
    "ADANIENT.NS",
    "MARUTI.NS",
    "TATAMOTORS.NS",
    "KOTAKBANK.NS",
    "ONGC.NS",
    "AXISBANK.BO",
    "TITAN.NS",
    "NTPC.NS",
    "ADANIGREEN.NS",
    "ULTRACEMCO.NS",
    "ASIANPAINT.NS",
    "ADANIPORTS.NS",
    "WIT",
    "COALINDIA.NS",
    "POWERGRID.NS",
    "BAJAJFINSV.NS",
    "DMART.NS",
    "FMGOETZE.NS",
    "HSIL.NS",
    "GEPIL.NS",
    "SPIC.NS",
    "MANGLMCEM.NS",
    "SIFY",
    "GEOJITFSL.NS",
    "TNPL.NS",
    "SHANKARA.NS",
    "GALLISPAT.NS",
    "NELCO.NS",
    "ASTEC.NS",
    "GATI.NS",
    "KITEX.NS",
    "INDNIPPON.NS",
    "NAVKARCORP.NS",
    "DHAMPURSUG.NS",
    "RANEHOLDIN.NS",
    "IGARASHI.NS",
    "HIMATSEIDE.NS",
    "WHEELS.NS",
    "IGPL.NS",
    "INEOSSTYRO.NS",
    "NACLIND.NS",
    "MANGCHEFER.NS",
    "KUANTUM.NS",
    "COSMOFIRST.NS",
    "BALAJITELE.NS",
    "JAYBARMARU.NS",
    "MONTECARLO.NS",
    "APTECHT.NS",
    "IMPAL.NS",
    "INDORAMA.NS",
    "KOKUYOCMLN.NS",
    "COFFEEDAY.NS",
    "BLISSGVS.NS",
    "STERTOOLS.NS",
    "RICOAUTO.NS",
    "OAL.NS",
    "HESTERBIO.NS",
    "SPENCERS.NS",
    "ORIENTPPR.NS",
    "EXCELINDUS.NS",
    "BODALCHEM.NS",
    "KELLTONTEC.NS",
    "NECLIFE.NS",
    "HMVL.NS",
    "3IINFOLTD.NS",
    "YTRA",
    "ASIANTILES.NS",
    "RADIOCITY.NS",
    "APEX.NS",
    "MIRZAINT.NS",
    "EBIXFOREX.NS",
    "RCOM.NS",
    "RBL.NS",
    "NBIFIN.NS",
    "NXTDIGITAL.NS",
    "ZEELEARN.NS",
    "MEP.NS",
    "MLKFOOD.BO",
    "FRETAIL.NS",
    "SREINFRA.NS",
    "JUMPNET.NS",
    "MODAIRY.BO",
    "FSC.NS"
        
]


# Counters
total_companies = len(ticker_symbols)
discarded_companies = 0
available_companies = 0

# Set start and end dates
start_date = '2014-01-01'
end_date = '2024-01-01'

# Create an empty DataFrame to store data for companies with sector and industry
all_stock_data = pd.DataFrame()

# Loop through each ticker symbol
for ticker_symbol in ticker_symbols:
    try:
        # Create a Ticker object
        ticker = yf.Ticker(ticker_symbol)

        # Get the info dictionary containing various information including sector and industry
        info = ticker.info

        # Get sector and industry information
        sector = info.get('sector')
        industry = info.get('industry')

        # Check if both sector and industry are not None
        if sector is not None and industry is not None:
            # Download historical data for the current ticker symbol
            stock_data = yf.download(ticker_symbol, start=start_date, end=end_date)

            # Add stock information as columns to the DataFrame
            stock_data['Company Name'] = info['longName']
            stock_data['Sector'] = sector
            stock_data['Industry'] = industry

            # Append the stock data to the DataFrame for all stocks
            all_stock_data = pd.concat([all_stock_data, stock_data])

            available_companies += 1
        else:
            discarded_companies += 1
    except HTTPError as e:
        if e.response.status_code == 404:
            print(f"Error 404: Ticker {ticker_symbol} not found. Discarding...")
            discarded_companies += 1

# Print summary
print("Summary:")
print("Total companies input:", total_companies)
print("Number of companies discarded:", discarded_companies)
print("Number of companies available with sector and industry:", available_companies)

# Display the DataFrame
print("\nStock Data:")
print(all_stock_data)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...
